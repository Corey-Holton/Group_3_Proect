# %%
import pretty_midi
import os
from pathlib import Path

# Import standard library modules
import sys

# Set the relative path to the project root directory
relative_path_to_root = "../../"

# Add the project root to the system path for importing in-house modules
sys.path.append(relative_path_to_root)

from utilities import modify_midi, detect_scale, print_available_modifications

# %% [markdown]
# ___

# %%
# Classical Style with Piano and Violin

midi_file = Path(r'C:\Users\chris\Code\AI-UTSA-2024\Projects\Group_3_Project\audio_processing\output_midi\input_5\other_basic_pitch.mid')

# Confirm file exists
if not midi_file.exists():
    print(f"File {midi_file} does not exist")
    exit()
    
input_midi_file = os.path.abspath(midi_file)
midi_data = pretty_midi.PrettyMIDI(input_midi_file)



modify_midi(
    input_midi_file=midi_data,
    output_midi_file="output_classical.mid",
    scale="C-1_major",
    instruments={0: "Acoustic Grand Piano", 1: "Violin"},
    tempo=100,
    transpose=0,
    duration_factor=1.2,
    swing=False,
    velocity_factor=1.0,
    arpeggiate=False,
    harmony=True,
    humanize=True,
    volume_effect={"value": 100, "time": 5.0}
)

# %%
# Jazz Style with Saxophone and Double Bass

midi_file = Path('./audio_processing/output_midi/input_5/other_basic_pitch.mid')

# Confirm file exists
if not midi_file.exists():
    print(f"File {midi_file} does not exist")
    exit()
    
input_midi_file = os.path.abspath(midi_file)
midi_data = pretty_midi.PrettyMIDI(input_midi_file)


modify_midi(
    input_midi_file=midi_data,
    output_midi_file="output_jazz.mid",
    scale="G-1_minor",
    instruments={0: "Alto Sax", 1: "Acoustic Bass"},
    tempo=120,
    transpose=2,
    duration_factor=0.8,
    swing=True,
    velocity_factor=1.2,
    arpeggiate=True,
    harmony=False,
    humanize=True,
    volume_effect={"value": 90, "time": 3.0}
)

# %%
# EDM Style with Synth Lead and Pad

# Define the input directory
midi_file = Path('./audio_processing/output_midi/input_5/other_basic_pitch.mid')

# Confirm file exists
if not midi_file.exists():
    print(f"File {midi_file} does not exist")
    exit()
    
input_midi_file = os.path.abspath(midi_file)
midi_data = pretty_midi.PrettyMIDI(input_midi_file)

modify_midi(
    input_midi_file=midi_data,
    output_midi_file="output_edm.mid",
    scale="D-1_major",
    instruments={0: "Synth Strings 1", 1: "Synth Strings 2"},
    tempo=140,
    transpose=-3,
    duration_factor=1.0,
    swing=False,
    velocity_factor=1.5,
    arpeggiate=False,
    harmony=False,
    humanize=False,
    volume_effect={"value": 127, "time": 0.0}
)

# %% [markdown]
# ___

# %%
from pprint import pprint

pprint(midi_data.__dict__)
# Out:
# {'_PrettyMIDI__tick_to_time': array([0.        , 0.00189394]),
#  '_tick_scales': [(0, 0.0018939440112316188)],
#  'instruments': [Instrument(program=0, is_drum=False, name="Acoustic Grand Piano")],
#  'key_signature_changes': [],
#  'lyrics': [],
#  'resolution': 220,
#  'text_events': [],
#  'time_signature_changes': [TimeSignature(numerator=4, denominator=4, time=0.0)]}

# %% [markdown]
# ___

# %%
pretty_midi.program_to_instrument_name(75)
pretty_midi.program_to_instrument_class(75)
pretty_midi.instrument_name_to_program("Acoustic Guitar (nylon)")

# %% [markdown]
# ___

# %%
def generate_note_list():
    """
    Generate a list of all possible MIDI note names (e.g., C0, C#0, D0, ..., G9).

    Returns:
        List[str]: A list of note names.
    """
    note_names = []
    pitch_map = ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']
    
    # MIDI note range is 0–127
    for octave in range(-1, 10):  # Octaves -1 to 9
        for pitch_class in pitch_map:
            note_names.append(f"{pitch_class}{octave}")
    
    return note_names

# Generate and print the list of note names
all_notes = generate_note_list()
for note in all_notes:
    print(note)
# Out:
# C-1
# C#-1
# D-1
# D#-1
# E-1
# F-1
# F#-1
# G-1
# G#-1
# A-1
# A#-1
# B-1
# C0
# C#0
# D0
# D#0
# E0
# F0
# F#0
# G0
# G#0
# A0
# A#0
# B0
# C1
# C#1
# D1
# D#1
# E1
# F1
# F#1
# G1
# G#1
# A1
# A#1
# B1
# C2
# C#2
# D2
# D#2
# E2
# F2
# F#2
# G2
# G#2
# A2
# A#2
# B2
# C3
# C#3
# D3
# D#3
# E3
# F3
# F#3
# G3
# G#3
# A3
# A#3
# B3
# C4
# C#4
# D4
# D#4
# E4
# F4
# F#4
# G4
# G#4
# A4
# A#4
# B4
# C5
# C#5
# D5
# D#5
# E5
# F5
# F#5
# G5
# G#5
# A5
# A#5
# B5
# C6
# C#6
# D6
# D#6
# E6
# F6
# F#6
# G6
# G#6
# A6
# A#6
# B6
# C7
# C#7
# D7
# D#7
# E7
# F7
# F#7
# G7
# G#7
# A7
# A#7
# B7
# C8
# C#8
# D8
# D#8
# E8
# F8
# F#8
# G8
# G#8
# A8
# A#8
# B8
# C9
# C#9
# D9
# D#9
# E9
# F9
# F#9
# G9
# G#9
# A9
# A#9
# B9

# %%
# Test note_name_to_number() with generated notes
for note in all_notes:
    try:
        print(f"{note}: {pretty_midi.note_name_to_number(note)}")
    except ValueError as e:
        print(f"Error with note {note}: {e}")
# Out:
# C-1: 0
# C#-1: 1
# D-1: 2
# D#-1: 3
# E-1: 4
# F-1: 5
# F#-1: 6
# G-1: 7
# G#-1: 8
# A-1: 9
# A#-1: 10
# B-1: 11
# C0: 12
# C#0: 13
# D0: 14
# D#0: 15
# E0: 16
# F0: 17
# F#0: 18
# G0: 19
# G#0: 20
# A0: 21
# A#0: 22
# B0: 23
# C1: 24
# C#1: 25
# D1: 26
# D#1: 27
# E1: 28
# F1: 29
# F#1: 30
# G1: 31
# G#1: 32
# A1: 33
# A#1: 34
# B1: 35
# C2: 36
# C#2: 37
# D2: 38
# D#2: 39
# E2: 40
# F2: 41
# F#2: 42
# G2: 43
# G#2: 44
# A2: 45
# A#2: 46
# B2: 47
# C3: 48
# C#3: 49
# D3: 50
# D#3: 51
# E3: 52
# F3: 53
# F#3: 54
# G3: 55
# G#3: 56
# A3: 57
# A#3: 58
# B3: 59
# C4: 60
# C#4: 61
# D4: 62
# D#4: 63
# E4: 64
# F4: 65
# F#4: 66
# G4: 67
# G#4: 68
# A4: 69
# A#4: 70
# B4: 71
# C5: 72
# C#5: 73
# D5: 74
# D#5: 75
# E5: 76
# F5: 77
# F#5: 78
# G5: 79
# G#5: 80
# A5: 81
# A#5: 82
# B5: 83
# C6: 84
# C#6: 85
# D6: 86
# D#6: 87
# E6: 88
# F6: 89
# F#6: 90
# G6: 91
# G#6: 92
# A6: 93
# A#6: 94
# B6: 95
# C7: 96
# C#7: 97
# D7: 98
# D#7: 99
# E7: 100
# F7: 101
# F#7: 102
# G7: 103
# G#7: 104
# ...

# %% [markdown]
# ___

# %%
def list_all_instruments():
    instrument_classes = pretty_midi.INSTRUMENT_CLASSES
    all_instruments = {}

    for i, instrument_class in enumerate(instrument_classes):
        all_instruments[instrument_class] = [
            pretty_midi.program_to_instrument_name(program)
            for program in range(i * 8, (i + 1) * 8)
        ]

    return all_instruments

list_all_instruments()
# Out:
# {'Piano': ['Acoustic Grand Piano',
#   'Bright Acoustic Piano',
#   'Electric Grand Piano',
#   'Honky-tonk Piano',
#   'Electric Piano 1',
#   'Electric Piano 2',
#   'Harpsichord',
#   'Clavinet'],
#  'Chromatic Percussion': ['Celesta',
#   'Glockenspiel',
#   'Music Box',
#   'Vibraphone',
#   'Marimba',
#   'Xylophone',
#   'Tubular Bells',
#   'Dulcimer'],
#  'Organ': ['Drawbar Organ',
#   'Percussive Organ',
#   'Rock Organ',
#   'Church Organ',
#   'Reed Organ',
#   'Accordion',
#   'Harmonica',
#   'Tango Accordion'],
#  'Guitar': ['Acoustic Guitar (nylon)',
#   'Acoustic Guitar (steel)',
#   'Electric Guitar (jazz)',
#   'Electric Guitar (clean)',
#   'Electric Guitar (muted)',
#   'Overdriven Guitar',
#   'Distortion Guitar',
#   'Guitar Harmonics'],
#  'Bass': ['Acoustic Bass',
#   'Electric Bass (finger)',
#   'Electric Bass (pick)',
#   'Fretless Bass',
#   'Slap Bass 1',
#   'Slap Bass 2',
#   'Synth Bass 1',
#   'Synth Bass 2'],
#  'Strings': ['Violin',
#   'Viola',
# ...
